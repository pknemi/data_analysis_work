# %%
import pandas as pd

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               6      148             72             35        0  33.6
# 1               1       85             66             29        0  26.6
# 2               8      183             64              0        0  23.3
# 3               1       89             66             23       94  28.1
# 4               0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 2455            3      126             88             41      235  39.3
# 2456            4      123             62              0        0  32.0
# 2457            1       80             74             11       60  30.0
# 2458            1       96             64             27       87  33.2
# 2459            6      105             70             32       68  30.8
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.627   50        1
# ...

# %% [markdown]
# # Find the total number of entries

# %%
df.info
# Out:
# <bound method DataFrame.info of       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               6      148             72             35        0  33.6
# 1               1       85             66             29        0  26.6
# 2               8      183             64              0        0  23.3
# 3               1       89             66             23       94  28.1
# 4               0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 2455            3      126             88             41      235  39.3
# 2456            4      123             62              0        0  32.0
# 2457            1       80             74             11       60  30.0
# 2458            1       96             64             27       87  33.2
# 2459            6      105             70             32       68  30.8
#
#       DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# # check if there is any null values

# %%
df.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
df.shape
# Out:
# (2460, 9)

# %%
df.size
# Out:
# 22140

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# # 1 Describe the data

# %%
df.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2460.000000  2460.000000    2460.000000    2460.000000  2460.000000
# mean      3.817480   121.602033      68.915041      20.531301    80.119919
# std       3.296458    31.789270      19.082655      15.716901   116.765807
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000   100.000000      64.000000       0.000000     0.000000
# 50%       3.000000   117.000000      70.000000      23.000000    36.000000
# 75%       6.000000   142.000000      80.000000      33.000000   129.000000
# max      17.000000   197.000000     122.000000      63.000000   846.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2460.000000               2460.000000  2460.000000  2460.000000
# mean     31.990447                  0.491440    32.821951     0.390244
# std       7.802569                  0.363917    11.251208     0.487904
# ...

# %%
#the highest number pf pregnencies is 17.highest glucose level is 197 and BMI is 67

# %% [markdown]
# # 2# Find the number of persons having glucose>70

# %%
df[df["Glucose"]>70]
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               6      148             72             35        0  33.6
# 1               1       85             66             29        0  26.6
# 2               8      183             64              0        0  23.3
# 3               1       89             66             23       94  28.1
# 4               0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 2455            3      126             88             41      235  39.3
# 2456            4      123             62              0        0  32.0
# 2457            1       80             74             11       60  30.0
# 2458            1       96             64             27       87  33.2
# 2459            6      105             70             32       68  30.8
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.627   50        1
# ...

# %%
df.axis=0

# %% [markdown]
# # 3What is the BMI  and Age of the persons having  glucose>180

# %%
df[df["Glucose"]>180].loc[:,["Age","BMI"]]
# Out:
#       Age   BMI
# 1515   31  36.7
# 408    39  25.9
# 1972   39  25.9
# 1918   53  30.5
# 1712   31  36.7
# ...   ...   ...
# 2032   38  34.1
# 1343   38  34.1
# 1998   38  34.1
# 486    38  34.1
# 1993   38  34.1
#
# [130 rows x 2 columns]

# %% [markdown]
# # 4Group by Outcome

# %%
df.groupby("Outcome").mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness    Insulin  \
# Outcome
# 0           3.242000  110.413333      67.852667      19.637333  69.938000
# 1           4.716667  139.084375      70.575000      21.928125  96.029167
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.066133                  0.444710  30.866000
# 1        34.997188                  0.564455  35.878125

# %% [markdown]
# # 5 most number of respondents  from which Age group

# %%
df["Age"].value_counts()
# Out:
# Age
# 21    214
# 22    203
# 25    183
# 24    135
# 29    122
# 23    113
# 26    101
# 27     98
# 28     93
# 41     85
# 31     84
# 33     76
# 30     74
# 36     69
# 37     69
# 42     65
# 38     61
# 32     49
# 34     46
# 43     41
# 40     39
# 35     37
# 46     35
# 51     33
# 47     27
# 44     26
# 39     26
# 45     24
# 58     24
# 57     21
# 60     19
# 50     17
# 54     15
# 65     15
# 49     14
# 52     14
# 62     13
# 63     11
# 55     10
# 48      9
# 61      9
# 56      8
# 81      7
# 72      6
# 66      5
# 59      5
# 69      4
# 53      4
# 67      2
# Name: count, dtype: int64

# %% [markdown]
# # 6.find the number of women with zero pregnency but diabetic,and find her BMI ,AGE,Blood pressure

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df[(df["Pregnancies"]==0) & (df["Outcome"]==1)].loc[:,["BMI","Age","BloodPressure"]]
# Out:
#        BMI  Age  BloodPressure
# 4     43.1   33             40
# 16    45.8   31             84
# 45    42.0   25             66
# 66    32.5   38             88
# 78    43.2   26              0
# ...    ...  ...            ...
# 2358  37.4   24             85
# 2400  37.4   24             85
# 2427  33.6   22             64
# 2436  31.6   32             88
# 2441  34.3   22             66
#
# [143 rows x 3 columns]

# %% [markdown]
# # 7. If BMI is greater than 30,find their age

# %%
filt=df["BMI"]>30

# %%
df.loc[filt,"Age"]
# Out:
# 1515    31
# 1918    53
# 1712    31
# 1598    31
# 228     31
#         ..
# 349     37
# 645     37
# 1511    22
# 973     22
# 935     37
# Name: Age, Length: 1523, dtype: int64

# %% [markdown]
# # 8 How many having diabetes below age 25

# %%
df[(df['Age']<25) & (df['Outcome']==1)]
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 109             0       95             85             25       36  37.4
# 110             3      171             72             33      135  33.3
# 124             0      113             76              0        0  33.3
# 197             3      107             62             13       48  22.9
# 213             0      140             65             26      130  42.6
# ...           ...      ...            ...            ...      ...   ...
# 2371            2      102             86             36      120  45.5
# 2400            0       95             85             25       36  37.4
# 2427            0      104             64             37       64  33.6
# 2441            0      131             66             40        0  34.3
# 2442            2      102             86             36      120  45.5
#
#       DiabetesPedigreeFunction  Age  Outcome
# 109                      0.247   24        1
# ...

# %% [markdown]
# # 9Response of first 20 respondents with "Pregnancies" ,"BMI","Glucose","Outcome"

# %%
df.loc[:20,["Pregnancies","BMI","Glucose","Outcome"]]
# Out:
#     Pregnancies   BMI  Glucose  Outcome
# 0             6  33.6      148        1
# 1             1  26.6       85        0
# 2             8  23.3      183        1
# 3             1  28.1       89        0
# 4             0  43.1      137        1
# 5             5  25.6      116        0
# 6             3  31.0       78        1
# 7            10  35.3      115        0
# 8             2  30.5      197        1
# 9             8   0.0      125        1
# 10            4  37.6      110        0
# 11           10  38.0      168        1
# 12           10  27.1      139        0
# 13            1  30.1      189        1
# 14            5  25.8      166        1
# 15            7  30.0      100        1
# 16            0  45.8      118        1
# 17            7  29.6      107        1
# 18            1  43.3      103        0
# 19            1  34.6      115        1
# 20            3  39.3      126        0

# %% [markdown]
# # 10.Rename the Column "Outcome"

# %%
ds=df.copy()

# %%
ds.rename(columns={"Outcome":"Diabetic"},inplace=True)

# %% [markdown]
# # 11.update the values of Outcome column into YES/No

# %%
df["Diabetic"].map({1:"Yes",2:"No"})
# Out:
# 1515    NaN
# 408     Yes
# 1972    Yes
# 1918    Yes
# 1712    NaN
#        ...
# 1511    NaN
# 973     NaN
# 2398    NaN
# 1720    NaN
# 935     Yes
# Name: Diabetic, Length: 2460, dtype: object

# %% [markdown]
# # 12.sort the data on the basis of highest glucose level recorded

# %%
df.sort_values(by="Glucose",ascending=False)
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1515            4      197             70             39      744  36.7
# 1023            8      197             74              0        0  25.9
# 408             8      197             74              0        0  25.9
# 668             4      197             70             39      744  36.7
# 574             4      197             70             39      744  36.7
# ...           ...      ...            ...            ...      ...   ...
# 1580            1        0             74             20       23  27.7
# 75              1        0             48             20        0  24.7
# 2171            5        0             80             32        0  41.0
# 1200            1        0             68             35        0  32.0
# 935             5        0             80             32        0  41.0
#
#       DiabetesPedigreeFunction  Age  Diabetic
# 1515                     2.329   31         0
# ...

# %% [markdown]
# # 13. Find number of respondents likely to be diabetic in future

# %%
df[(df["DiabetesPedigreeFunction"]>2)].loc[:,["Pregnancies","Glucose","SkinThickness","BMI","Age"]]
# Out:
#       Pregnancies  Glucose  SkinThickness   BMI  Age
# 1515            4      197             39  36.7   31
# 1712            4      197             39  36.7   31
# 1598            4      197             39  36.7   31
# 228             4      197             39  36.7   31
# 2180            4      197             39  36.7   31
# 2211            4      197             39  36.7   31
# 982             4      197             39  36.7   31
# 731             4      197             39  36.7   31
# 574             4      197             39  36.7   31
# 668             4      197             39  36.7   31
# 1989            0      180             63  59.4   25
# 1188            0      180             63  59.4   25
# 2305            0      180             63  59.4   25
# 1429            0      180             63  59.4   25
# 445             0      180             63  59.4   25
# 2076            3      173             48  38.4   25
# 2206            3      173             48  38.4   25
# ...

# %% [markdown]
# # 14. find Women who are diabetic with atleast one pregnancy,also find their skin thickness,bmi and age

# %%
df[(df["Pregnancies"]>=1) & (df["Diabetic"]==1)].loc[:,["Pregnancies","BMI","Age","SkinThickness"]]
# Out:
#       Pregnancies   BMI  Age  SkinThickness
# 408             8  25.9   39              0
# 1972            8  25.9   39              0
# 1918            2  30.5   53             45
# 1023            8  25.9   39              0
# 1227            2  30.5   53             45
# ...           ...   ...  ...            ...
# 1666            5  41.0   37             32
# 2171            5  41.0   37             32
# 349             5  41.0   37             32
# 645             5  41.0   37             32
# 935             5  41.0   37             32
#
# [817 rows x 4 columns]

# %% [markdown]
# # 15.find no.of diabetic respondents whose skin thicness greater than 18 and blood pressure>79

# %%
df[(df['SkinThickness']>18) & (df['BloodPressure']>79)].loc[:,:]
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2087            0      189            104             25        0  34.3
# 440             0      189            104             25        0  34.3
# 1911            0      189            104             25        0  34.3
# 1423            0      189            104             25        0  34.3
# 533             7      184             84             33        0  35.5
# ...           ...      ...            ...            ...      ...   ...
# 1666            5        0             80             32        0  41.0
# 2171            5        0             80             32        0  41.0
# 349             5        0             80             32        0  41.0
# 645             5        0             80             32        0  41.0
# 935             5        0             80             32        0  41.0
#
#       DiabetesPedigreeFunction  Age  Diabetic
# 2087                     0.435   41         1
# ...

# %% [markdown]
# # 16.find the number of high risk diabetic patients

# %%
df[(df['Pregnancies']>=1) & (df['BMI']>30) & (df["Age"]>45) & (df["BloodPressure"]>79) &(df["SkinThickness"]>18) & (df["Diabetic"]==1)].loc[:,:]
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1704            7      181             84             21      192  35.9
# 236             7      181             84             21      192  35.9
# 1787            7      181             84             21      192  35.9
# 2261            7      181             84             21      192  35.9
# 2279            8      176             90             34      300  33.7
# 53              8      176             90             34      300  33.7
# 499             8      176             90             34      300  33.7
# 937             8      176             90             34      300  33.7
# 2134            8      176             90             34      300  33.7
# 2448            8      176             90             34      300  33.7
# 2077            8      176             90             34      300  33.7
# 1530            8      176             90             34      300  33.7
# ...

# %% [markdown]
# # 17.sort values by highest glucose,bmi,age

# %%
df.sort_values(["Glucose","BMI","Age"],ascending=[False,False,False])
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1515            4      197             70             39      744  36.7
# 1712            4      197             70             39      744  36.7
# 1598            4      197             70             39      744  36.7
# 228             4      197             70             39      744  36.7
# 2180            4      197             70             39      744  36.7
# ...           ...      ...            ...            ...      ...   ...
# 1797            1        0             74             20       23  27.7
# 1720            1        0             74             20       23  27.7
# 75              1        0             48             20        0  24.7
# 1613            1        0             48             20        0  24.7
# 2398            1        0             48             20        0  24.7
#
#       DiabetesPedigreeFunction  Age  Diabetic
# 1515                     2.329   31         0
# ...

# %%
df["Glucose"].max()
# Out:
# 197

# %%
df["Age"].min()
# Out:
# 21

# %%
1

# %%
df["BloodPressure"].nlargest(10)
# Out:
# 1381    122
# 106     122
# 1964    122
# 1765    122
# 43      110
# 1859    110
# 925     110
# 177     110
# 1297    110
# 2303    110
# Name: BloodPressure, dtype: int64

# %%
df["BMI"].nlargest(5)
# Out:
# 177     67.1
# 1297    67.1
# 2303    67.1
# 1989    59.4
# 1188    59.4
# Name: BMI, dtype: float64

# %% [markdown]
# # 18.Smallest 10 BMI 's

# %%
df["BMI"].nsmallest(10)
# Out:
# 1637    0.0
# 526     0.0
# 776     0.0
# 2453    0.0
# 2435    0.0
# 2016    0.0
# 9       0.0
# 2264    0.0
# 2175    0.0
# 906     0.0
# Name: BMI, dtype: float64

# %% [markdown]
# # 19. Average glucose value

# %%
df["Glucose"].mean()
# Out:
# 121.60203252032521

# %% [markdown]
# # 20 find age and insulin of diabetic patients having skinthickness>18

# %%
df[(df["Diabetic"]==1) & (df["SkinThickness"]>18)].loc[:,["Age","BMI"]]
# Out:
#       Age   BMI
# 1918   53  30.5
# 1227   53  30.5
# 1980   53  30.5
# 8      53  30.5
# 359    29  36.5
# ...   ...   ...
# 1666   37  41.0
# 2171   37  41.0
# 349    37  41.0
# 645    37  41.0
# 935    37  41.0
#
# [605 rows x 2 columns]
